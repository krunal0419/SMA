# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

apple_data=pd.read_csv('sentiment_analysis_apple.csv')

print(apple_data.head())

apple_sentiments=apple_data.groupby('sentiment_label')['comment_text'].count()

fig, ax=plt.subplots()
apple_sentiments.plot(kind='bar', position=0, width=0.4, color='green')
ax.set_xlabel('Sentiments')
ax.set_ylabel('Tweet frequency')
ax.legend()
plt.show()
# Out:
#                                         comment_text  sentiment_polarity  \
# 0  Platinum Car Charger for Samsung Mobile Featur...              0.0000
# 1  We just had to do it!! :) ;) :)\n\nMinecraft V...              0.8168
# 2  Samsung's Next-Gen Smartwatch Could Offer Mobi...              0.0000
# 3  Hype Video Broadcast App Has Niche Potential\n...              0.0000
# 4  The radiation that can cause cancer from Samsu...             -0.8070
#
#   sentiment_label
# 0         neutral
# 1        positive
# 2         neutral
# 3         neutral
# 4        negative
